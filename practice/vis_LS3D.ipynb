# %%
# %matplotlib inline
import numpy as np
import torch
from torch.utils.serialization import load_lua
import os
import scipy.io as sio
import cv2
import math
from matplotlib import pyplot as plt
import imp

utils = imp.load_source('utils', '../code/utils.py')

# %%
TRAIN_DATA_DIR = '/Data/nruiz9/data/facial_landmarks/LS3D-W/'

# %%
idx = 

dir_name = '/Data/nruiz9/data/facial_landmarks/LS3D-W/300VW-3D/Trainset/001'
img_path = os.path.join(dir_name, sorted(os.listdir(dir_name))[idx].split('.')[0] + '.jpg')
print img_path
img_name = img_path.split('.')[0]

img = cv2.imread(img_path)

annot = load_lua(img_name + '.t7')

# yaw = float(annot[1]) * 180 / np.pi
# pitch = float(annot[2]) * 180 / np.pi
# roll = float(annot[3]) * 180 / np.pi
# if yaw < 0:
#     roll *= -1

# utils.plot_pose_cube(img, yaw, pitch, roll)

img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

plt.imshow(img)
plt.show()
# print 'yaw, pitch, roll: ', yaw, pitch, roll
# Out:
# /Data/nruiz9/data/facial_landmarks/LS3D-W/300VW-3D/Trainset/001/0071.jpg
